# %%
import pandas as pd
f=pd.read_csv("fortune1000.csv",index_col="Rank")
s=f.groupby("Sector")

# %%
#f["Sector"].nunique()
len(s)
# Out:
# 21

# %%
#f["Sector"].value_counts()
s.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
s.first() #first row of each group
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
s.last() #last row of each group
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
s.groups
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %%
#f[f["Sector"]=="Technology"]
s.get_group("Technology")
# Out:
#                     Company                                    Industry  \
# Rank
# 3                     Apple                 Computers, Office Equipment
# 18               Amazon.com             Internet Services and Retailing
# 20                       HP                 Computers, Office Equipment
# 25                Microsoft                           Computer Software
# 31                      IBM             Information Technology Services
# ...                     ...                                         ...
# 970       Rackspace Hosting             Internet Services and Retailing
# 971        VeriFone Systems                 Computers, Office Equipment
# 975    Super Micro Computer                 Computers, Office Equipment
# 984   Nuance Communications                           Computer Software
# 990             F5 Networks  Network and Other Communications Equipment
#
#              Location  Revenue  Profits  Employees
# Rank
# ...

# %%
s.max() #applies to column next to index here its "Company"
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                         Woodward
# Apparel                         Wolverine World Wide
# Business Services                      Western Union
# Chemicals                          Westlake Chemical
# Energy                                   Xcel Energy
# Engineering & Construction              Tutor Perini
# Financials                            Zions Bancorp.
# Food and Drug Stores              Whole Foods Market
# Food, Beverages & Tobacco            WhiteWave Foods
# Health Care                          inVentiv Health
# Hotels, Resturants & Leisure              Yum Brands
# Household Products                     Vista Outdoor
# Industrials                       Zebra Technologies
# Materials                     Worthington Industries
# Media                                    iHeartMedia
# Motor Vehicles & Parts               Wabash National
# ...

# %%
s.sum()  # mean()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
s["Revenue"].sum()
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
s["Revenue","Profits"].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                    Revenue      Profits
# Sector
# Aerospace & Defense           17897.000000  1437.100000
# Apparel                        6397.866667   549.066667
# Business Services              5337.156863   553.470588
# Chemicals                      8129.900000   754.266667
# Energy                        12441.057377  -602.024590
# Engineering & Construction     5922.423077   204.000000
# Financials                    15950.784173  1872.007194
# Food and Drug Stores          32251.266667  1117.266667
# Food, Beverages & Tobacco     12929.465116  1195.744186
# Health Care                   21529.426667  1414.853333
# Hotels, Resturants & Leisure   6781.840000   827.880000
# ...

# %%
s.agg({"Revenue" : "sum",
      "Profits" : ["sum","mean"],
      "Employees" : "mean"})
# Out:
#                               Revenue Profits                  Employees
#                                   sum     sum         mean          mean
# Sector
# Aerospace & Defense            357940   28742  1437.100000  48402.850000
# Apparel                         95968    8236   549.066667  23093.133333
# Business Services              272195   28227   553.470588  26687.254902
# Chemicals                      243897   22628   754.266667  15455.033333
# Energy                        1517809  -73447  -602.024590   9745.303279
# Engineering & Construction     153983    5304   204.000000  15642.615385
# Financials                    2217159  260209  1872.007194  24172.287770
# Food and Drug Stores           483769   16759  1117.266667  93026.533333
# Food, Beverages & Tobacco      555967   51417  1195.744186  28177.488372
# Health Care                   1614707  106114  1414.853333  35710.520000
# Hotels, Resturants & Leisure   169546   20697   827.880000  99369.800000
# ...

# %%
s1=f.groupby(["Revenue","Profits"])

# %%
s1.size()
# Out:
# Revenue  Profits
# 1895      46        1
# 1896      161       1
# 1898      172       2
# 1902     -47        1
# 1908     -3748      1
#                    ..
# 181241    1476      1
# 210821    24083     1
# 233715    53394     1
# 246204    16150     1
# 482130    14694     1
# Length: 996, dtype: int64

# %%
s1.sum()
# Out:
#                  Employees
# Revenue Profits
# 1895     46           5480
# 1896     161         21200
# 1898     172          5292
# 1902    -47           3448
# 1908    -3748          665
# ...                    ...
# 181241   1476        70400
# 210821   24083      331000
# 233715   53394      110000
# 246204   16150       75600
# 482130   14694     2300000
#
# [996 rows x 1 columns]

# %%
df=pd.DataFrame(columns=f.columns)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for sector,data in s:  # data in each sector in s
    highest_in_sector=data.nlargest(1,"Revenue")
    df=df.append(highest_in_sector)
df
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
cities=f.groupby("Location")
df1=pd.DataFrame(columns=f.columns)
df1
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
cities.groups
# Out:
# {'Abbott Park, IL': Int64Index([138], dtype='int64', name='Rank'),
#  'Akron, OH': Int64Index([169, 188], dtype='int64', name='Rank'),
#  'Allentown, PA': Int64Index([288, 350, 548], dtype='int64', name='Rank'),
#  'Angleton, TX': Int64Index([830], dtype='int64', name='Rank'),
#  'Ankeny, IA': Int64Index([374], dtype='int64', name='Rank'),
#  'Ann Arbor, MI': Int64Index([915], dtype='int64', name='Rank'),
#  'Annapolis Junction, MD': Int64Index([596], dtype='int64', name='Rank'),
#  'Arden Hills, MN': Int64Index([215], dtype='int64', name='Rank'),
#  'Arlington, VA': Int64Index([190, 626, 673, 737], dtype='int64', name='Rank'),
#  'Armonk, NY': Int64Index([31], dtype='int64', name='Rank'),
#  'Atlanta, GA': Int64Index([ 28,  48,  62,  68, 162, 183, 249, 320, 323, 329, 397, 433, 434,
#              529, 577, 600, 613, 689, 726, 777, 789, 801, 991],
#             dtype='int64', name='Rank'),
#  'Auburn Hills, MI': Int64Index([310, 339], dtype='int64', name='Rank'),
# ...

# %%
for city,i in cities: # each city is considered i for each itteration for all cities 
    a=i.nlargest(1,"Revenue")
    df1=df1.append(a)
df1
# Out:
#                       Company                        Sector  \
# 138       Abbott Laboratories                   Health Care
# 169    Goodyear Tire & Rubber        Motor Vehicles & Parts
# 288  Air Products & Chemicals                     Chemicals
# 830     Benchmark Electronics                    Technology
# 374    Casey’s General Stores                     Retailing
# ..                        ...                           ...
# 7                  CVS Health          Food and Drug Stores
# 506   Hanover Insurance Group                    Financials
# 764      Penn National Gaming  Hotels, Resturants & Leisure
# 773            Bon-Ton Stores                     Retailing
# 932             Herman Miller            Household Products
#
#                                            Industry         Location Revenue  \
# 138                  Medical Products and Equipment  Abbott Park, IL   20661
# 169                        Motor Vehicles and Parts        Akron, OH   16443
# ...
